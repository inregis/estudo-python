# %% [markdown]
# ### Exemplo de erros

# %%
numero = 10/0
print(numero)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 numero = 10/0
#       2 print(numero)
#
# ZeroDivisionError: division by zero

# %%
numero = int("abc")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 numero = int("abc")
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
try:
    numero = 10/0
    print(numero)
except ZeroDivisionError:
    print("Erro: Divisão por zero")
# Out:
# Erro: Divisão por zero

# %%
try:
    numero = int("10")
    print(numero)
except ValueError:
    print("Erro de conversão")
finally:
    print("Execução finalizada")
# Out:
# 10
# Execução finalizada

# %%
try:
    numero = int("abc")
    print(numero)
except ValueError:
    print("Erro de conversão")
finally:
    print("Execução finalizada")
# Out:
# Erro de conversão
# Execução finalizada

# %%
idade = -5
if idade < 0:
    raise ValueError("Idade não pode ser negativa")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 idade = -5
#       2 if idade < 0:
# ----> 3     raise ValueError("Idade não pode ser negativa")
#
# ValueError: Idade não pode ser negativa

# %%
numero = 10
divisor = 0
print('numero:', numero)
print('divisor:', divisor)

resultado = numero / divisor
# Out:
# numero: 10
# divisor: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 6
#       2 divisor = 0
#       3 print('numero:', numero)
#       4 print('divisor:', divisor)
#       5
# ----> 6 resultado = numero / divisor
#
# ZeroDivisionError: division by zero

# %%
def dividir(a, b):
    return a / b
dividir(10, 0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 def dividir(a, b):
#       2     return a / b
# ----> 3 dividir(10, 0)
#
# Cell In[7], line 2, in dividir(a, b)
#       1 def dividir(a, b):
# ----> 2     return a / b
#
# ZeroDivisionError: division by zero

# %%
import logging
logging.basicConfig(level=logging.INFO)
logging.info("Programa iniciado")
# Out:
# INFO:root:Programa iniciado

# %%
import logging
logging.basicConfig(level=logging.DEBUG)
logging.debug("Mensagem de debug")
logging.info("Mensagem de info")
logging.warning("Mensagem de aviso")
logging.error("Mensagem de erro")
# Out:
# DEBUG:root:Mensagem de debug
# INFO:root:Mensagem de info
# WARNING:root:Mensagem de aviso
# ERROR:root:Mensagem de erro

# %%
numero = input("Digite um número: ")
if numero.isdigit():
    numero = int(numero)
    print(numero)
else:
    print("Entrada inválida: não é um número")
# Out:
# Entrada inválida: não é um número

# %%
try:
    numero = int(input("Digite um número: "))
    print(10/numero)
except ValueError:
    print("Entrada inválida: não é um número")
except ZeroDivisionError:
    print("Erro: divisão por zero não é permitida.")
# Out:
# 5.0
